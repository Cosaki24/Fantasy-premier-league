# %%
import requests, json, pandas as pd

# Pulling data from Premier League

pd.options.display.max_rows = 200
fpl_api_url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
response = requests.get(fpl_api_url).json()
fpl_data = json.dumps(response)

# The data above has many information, but we are only interested with the players('elements'). So we are going
# to separate it into the player table, with few columns which we are interested with 
# and sort
players_info = pd.json_normalize(json.loads(fpl_data), 'elements', sep='_')

columns_to_be_used = [
    'first_name', 
    'second_name',
    'web_name',  # name that appears on the team sheet
    'now_cost', # current price, multiply with 0.1 to get value that is displayed in the app e.g 76 means price is 7.6m
    'total_points', # 2024/25 season cumulative points
    'ict_index',  # influence, creativity, threat, the higher the better
    'team',       # player club
    'points_per_game',
    'starts',      # no of times player made into the starting eleven
    'element_type',  # player position (1 = GK, 2 = DEF, 3 = MID, 4 = FWD)
    'value_season'   # points produced in relation to player cost, in other words return on investment (ROI). The higher the better.
]

players_info_with_selected_columns = players_info[columns_to_be_used]
players_info_with_selected_columns[['value_season', 'ict_index', 'points_per_game']] = players_info_with_selected_columns[['value_season','ict_index', 'points_per_game']].apply(pd.to_numeric) 
players_table = players_info_with_selected_columns.sort_values(by='value_season', ascending=False) # sorting by value season
players_table.head(100)  # change the number to change number of rows displayed

# take a moment and study the data below, you might notice something helpful
# Out:
# C:\Users\colly\AppData\Local\Temp\ipykernel_48712\2819313490.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_info_with_selected_columns[['value_season', 'ict_index', 'points_per_game']] = players_info_with_selected_columns[['value_season','ict_index', 'points_per_game']].apply(pd.to_numeric)
#               first_name                second_name          web_name  \
# 116                Bryan                     Mbeumo            Mbeumo
# 302                 Alex                      Iwobi             Iwobi
# 541                 Matz                       Sels              Sels
# 544                Chris                       Wood              Wood
# 279               Jordan                   Pickford          Pickford
# 282               Ashley                      Young             Young
# 471                André                      Onana             Onana
# 548               Nikola                 Milenković        Milenković
# 670              Matheus   Santos Carneiro Da Cunha             Cunha
# 237                 Dean                  Henderson         Henderson
# 452                 Amad                     Diallo              Amad
# 520                  Ola                       Aina              Aina
# 127                Yoane                      Wissa             Wissa
# 106               Mikkel                  Damsgaard         Damsgaard
# 534              Murillo  Santiago Costa dos Santos           Murillo
# 275               Dwight                     McNeil            McNeil
# 607                James                   Maddison          Maddison
# 378                Jamie                      Vardy             Vardy
# 171                Danny                    Welbeck           Welbeck
# 208                 Noni                    Madueke           Madueke
# 694               Jørgen              Strand Larsen     Strand Larsen
# 83                Justin                   Kluivert          Kluivert
# 199                 Enzo                  Fernández              Enzo
# 405              Mohamed                      Salah           M.Salah
# 216               Robert                    Sánchez           Sánchez
# 310              Antonee                   Robinson          Robinson
# 59                Morgan                     Rogers            Rogers
# 307                 Raúl                    Jiménez              Raúl
# 213                 Cole                     Palmer            Palmer
# 11                 David                Raya Martin              Raya
# 649                Tomáš                     Souček            Souček
# 494                Lewis                       Hall              Hall
# 2                Gabriel       dos Santos Magalhães           Gabriel
# 292                Emile                 Smith Rowe        Smith Rowe
# 123                Kevin                     Schade            Schade
# 246               Daniel                      Muñoz             Muñoz
# 108                 Mark                    Flekken           Flekken
# 608                Pedro                      Porro       Pedro Porro
# 211              Nicolas                    Jackson         N.Jackson
# 604              Brennan                    Johnson           Johnson
# 105               Nathan                    Collins           Collins
# 100  Francisco Evanilson            de Lima Barbosa         Evanilson
# 82                 Milos                     Kerkez            Kerkez
# 276              Vitalii                  Mykolenko         Mykolenko
# 431                Joško                   Gvardiol          Gvardiol
# 329                 Liam                      Delap             Delap
# 236                 Marc                      Guéhi             Guéhi
# 605                Dejan                 Kulusevski        Kulusevski
# 280                James                  Tarkowski         Tarkowski
# 631                Aaron                Wan-Bissaka       Wan-Bissaka
# 635               Jarrod                      Bowen             Bowen
# 13                Bukayo                       Saka              Saka
# 354              Facundo                 Buonanotte        Buonanotte
# 347             Arijanet                      Muric             Muric
# 415               Virgil                   van Dijk            Virgil
# 189               Moisés             Caicedo Corozo           Caicedo
# 404                 Luis                       Díaz         Luis Díaz
# 457                Diogo             Dalot Teixeira             Dalot
# 488               Harvey                     Barnes            Barnes
# 478             Noussair                   Mazraoui          Mazraoui
# 14               William                     Saliba            Saliba
# 15                Thomas                     Partey            Thomas
# 508                 Nick                       Pope              Pope
# 89               Antoine                    Semenyo           Semenyo
# 454                Bruno           Borges Fernandes       B.Fernandes
# 177            Georginio                     Rutter         Georginio
# 159               Mitoma                      Kaoru            Mitoma
# 253              Ismaïla                       Sarr            I.Sarr
# 245               Tyrick                   Mitchell          Mitchell
# 303                Bernd                       Leno              Leno
# 41                 Lucas                      Digne             Digne
# 5                Jurriën                     Timber          J.Timber
# 532               Callum                Hudson-Odoi       Hudson-Odoi
# 468             Lisandro                   Martínez          Martinez
# 686                Mario                     Lemina         Mario Jr.
# 496            Alexander                       Isak              Isak
# 328                 Leif                      Davis             Davis
# 403             Ibrahima                     Konaté            Konaté
# 52              Emiliano            Martínez Romero          Martinez
# 152           João Pedro         Junqueira de Jesus        João Pedro
# 111               Vitaly                     Janelt            Janelt
# 389                Trent           Alexander-Arnold  Alexander-Arnold
# 258              Maxence                    Lacroix           Lacroix
# 294                Adama                     Traoré             Adama
# 682          João Victor             Gomes da Silva           J.Gomes
# 521               Elliot                   Anderson          Anderson
# 63                 Ollie                    Watkins           Watkins
# 93                Marcus                  Tavernier         Tavernier
# 491                  Dan                       Burn              Burn
# 646                Lucas   Tolentino Coelho de Lima         L.Paquetá
# 228               Trevoh                   Chalobah          Chalobah
# 497                Jacob                     Murphy          J.Murphy
# 493              Anthony                     Gordon            Gordon
# 435                Mateo                    Kovačić           Kovačić
# 76                 Lewis                       Cook              Cook
# 477             Matthijs                    de Ligt           De Ligt
# 365                 Mads                  Hermansen         Hermansen
# 643                  Max                     Kilman            Kilman
# 662                Rayan                  Aït-Nouri         Aït-Nouri
# 265              Dominic              Calvert-Lewin     Calvert-Lewin
#
#      now_cost  total_points  ict_index  team  points_per_game  starts  \
# 116        76           105      132.5     4              6.6      16
# 302        57            78      116.4     9              4.9      16
# 541        47            64       36.0    16              4.0      16
# 544        66            90       91.6    16              5.6      15
# 279        49            66       38.6     8              4.4      15
# 282        47            62       55.9     8              4.8      13
# 471        52            67       37.8    14              4.2      16
# 548        46            59       49.7    16              3.9      15
# 670        71            89      134.3    20              5.6      15
# 237        44            55       42.3     7              3.4      16
# 452        52            65       88.1    14              4.6       9
# 520        49            60       44.1    16              3.8      16
# 127        62            75       80.3     4              5.8      12
# 106        50            60       86.8     4              3.8      13
# 534        46            55       64.8    16              3.4      16
# 275        54            65      100.5     8              5.0      13
# 607        76            91      130.6    18              5.7      13
# 378        56            67       69.5    11              4.5      15
# 171        58            69       83.7     5              4.9      13
# 208        63            75      116.8     6              5.0      13
# 694        57            67       83.8    20              4.2      16
# 83         55            65       93.2     3              4.1      13
# 199        51            59       88.8     6              3.9      11
# 405       134           156      188.1    12             10.4      15
# 216        48            55       39.4     6              3.7      15
# 310        48            55       82.1     9              3.4      16
# 59         53            61       90.1     2              3.8      16
# 307        55            63       80.9     9              3.9      12
# 213       112           128      178.3     6              8.0      16
# 11         56            64       35.2     1              4.0      16
# 649        49            56       70.1    19              3.7      12
# 494        46            52       76.9    15              3.2      13
# 2          61            69       64.8     1              4.9      14
# 292        55            61       66.9     9              3.8      14
# 123        51            56       57.7     4              3.5       7
# 246        47            51       78.5     7              3.2      16
# 108        45            49       64.4     4              3.1      16
# 608        56            61       93.1    18              3.8      14
# 211        82            89      119.3     6              5.9      15
# 604        66            71       96.8    18              4.4      13
# 105        45            48       77.3     4              3.0      16
# 100        61            65       81.7     3              4.3      14
# 82         47            50       64.0     3              3.1      16
# 276        43            45       33.8     8              3.5      13
# 431        61            64       97.3    13              4.3      14
# 329        56            59       76.8    10              3.7      15
# 236        45            47       64.3     7              2.9      16
# 605        63            65      124.5    18              4.1      14
# 280        48            49       59.6     8              3.3      15
# 631        46            47       61.0    19              3.1      14
# 635        74            75      137.4    19              4.7      16
# 13        106           106      174.9     1              7.1      15
# 354        50            50       82.4    11              3.8      10
# 347        44            44       45.6    10              2.9      15
# 415        65            65       55.1    12              4.3      15
# 189        49            49       66.5     6              3.1      16
# 404        74            73       85.0    12              4.9      10
# 457        52            51       50.6    14              3.2      16
# 488        62            61       67.2    15              3.8       6
# 478        47            46       44.2    14              2.9      14
# 14         63            61       45.4     1              4.1      15
# 15         50            48       54.1     1              3.2      13
# 508        50            48       39.1    15              3.2      15
# 89         57            55      110.9     3              3.7      15
# 454        84            81      118.2    14              5.1      16
# 177        55            52       53.8     5              3.5      12
# 159        66            63      109.8     5              3.9      15
# 253        57            54       84.1     7              3.4       9
# 245        48            45       58.7     7              2.8      16
# 303        50            47       40.2     9              2.9      16
# 41         47            44       68.8     2              2.8      14
# 5          57            53       51.4     1              3.8      13
# 532        54            50       77.8    16              3.3      13
# 468        44            41       41.4    14              3.2      13
# 686        50            46       62.4    20              2.9      15
# 496        87            80      113.8    15              5.7      14
# 328        45            41       90.1    10              2.6      16
# 403        51            46       34.2    12              3.8      11
# 52         50            45       34.9     2              2.8      16
# 152        59            53       66.2     5              5.3       8
# 111        49            44       50.1     4              2.9      13
# 389        70            62       70.1    12              4.4      13
# 258        45            40       39.7     7              3.1      13
# 294        48            42       67.1     9              2.8      10
# 682        49            43       50.1    20              2.9      15
# 521        50            44       78.6    16              2.9      11
# 63         89            78      105.5     2              4.9      14
# 93         55            48       97.1     3              3.2      13
# 491        44            38       38.1    15              2.5      15
# 646        57            49       71.6    19              3.1      13
# 228        44            38       41.7     7              3.8      10
# 497        49            42       52.4    15              3.2       9
# 493        72            61      115.1    15              4.1      14
# 435        54            46       61.3    13              3.8      10
# 76         50            42       73.3     3              2.8      14
# 477        50            42       46.3    14              2.6      13
# 365        45            38       51.5    11              2.4      16
# 643        45            38       61.0    19              2.4      16
# 662        48            40       76.7    20              2.5      16
# 265        55            45       65.0     8              3.0      14
#
#      element_type  value_season
# 116             3          13.8
# 302             3          13.7
# 541             1          13.6
# 544             4          13.6
# 279             1          13.5
# 282             2          13.2
# 471             1          12.9
# 548             2          12.8
# 670             4          12.5
# 237             1          12.5
# 452             3          12.5
# 520             2          12.2
# 127             4          12.1
# 106             3          12.0
# 534             2          12.0
# 275             3          12.0
# 607             3          12.0
# 378             4          12.0
# 171             4          11.9
# 208             3          11.9
# 694             4          11.8
# 83              3          11.8
# 199             3          11.6
# 405             3          11.6
# 216             1          11.5
# 310             2          11.5
# 59              3          11.5
# 307             4          11.5
# 213             3          11.4
# 11              1          11.4
# 649             3          11.4
# 494             2          11.3
# 2               2          11.3
# 292             3          11.1
# 123             3          11.0
# 246             2          10.9
# 108             1          10.9
# 608             2          10.9
# 211             4          10.9
# 604             3          10.8
# 105             2          10.7
# 100             4          10.7
# 82              2          10.6
# 276             2          10.5
# 431             2          10.5
# 329             4          10.5
# 236             2          10.4
# 605             3          10.3
# 280             2          10.2
# 631             2          10.2
# 635             3          10.1
# 13              3          10.0
# 354             3          10.0
# 347             1          10.0
# 415             2          10.0
# 189             3          10.0
# 404             3           9.9
# 457             2           9.8
# 488             3           9.8
# 478             2           9.8
# 14              2           9.7
# 15              3           9.6
# 508             1           9.6
# 89              3           9.6
# 454             3           9.6
# 177             3           9.5
# 159             3           9.5
# 253             3           9.5
# 245             2           9.4
# 303             1           9.4
# 41              2           9.4
# 5               2           9.3
# 532             3           9.3
# 468             2           9.3
# 686             3           9.2
# 496             4           9.2
# 328             2           9.1
# 403             2           9.0
# 52              1           9.0
# 152             4           9.0
# 111             3           9.0
# 389             2           8.9
# 258             2           8.9
# 294             3           8.8
# 682             3           8.8
# 521             3           8.8
# 63              4           8.8
# 93              3           8.7
# 491             2           8.6
# 646             3           8.6
# 228             2           8.6
# 497             3           8.6
# 493             3           8.5
# 435             3           8.5
# 76              3           8.4
# 477             2           8.4
# 365             1           8.4
# 643             2           8.4
# 662             2           8.3
# 265             4           8.2

# %%
# Interesting results above, huh?
# let's sort by total points
players_table_sorted_by_total_points = players_info_with_selected_columns.sort_values(by='total_points', ascending=False)
players_table_sorted_by_total_points.head(100)  # change the number to change the number of rows displayed
# Out:
#               first_name                second_name          web_name  \
# 405              Mohamed                      Salah           M.Salah
# 213                 Cole                     Palmer            Palmer
# 13                Bukayo                       Saka              Saka
# 116                Bryan                     Mbeumo            Mbeumo
# 432               Erling                    Haaland           Haaland
# 607                James                   Maddison          Maddison
# 544                Chris                       Wood              Wood
# 211              Nicolas                    Jackson         N.Jackson
# 670              Matheus   Santos Carneiro Da Cunha             Cunha
# 454                Bruno           Borges Fernandes       B.Fernandes
# 496            Alexander                       Isak              Isak
# 302                 Alex                      Iwobi             Iwobi
# 63                 Ollie                    Watkins           Watkins
# 615                  Son                  Heung-min               Son
# 208                 Noni                    Madueke           Madueke
# 635               Jarrod                      Bowen             Bowen
# 127                Yoane                      Wissa             Wissa
# 404                 Luis                       Díaz         Luis Díaz
# 604              Brennan                    Johnson           Johnson
# 171                Danny                    Welbeck           Welbeck
# 2                Gabriel       dos Santos Magalhães           Gabriel
# 471                André                      Onana             Onana
# 378                Jamie                      Vardy             Vardy
# 694               Jørgen              Strand Larsen     Strand Larsen
# 279               Jordan                   Pickford          Pickford
# 83                Justin                   Kluivert          Kluivert
# 452                 Amad                     Diallo              Amad
# 415               Virgil                   van Dijk            Virgil
# 605                Dejan                 Kulusevski        Kulusevski
# 100  Francisco Evanilson            de Lima Barbosa         Evanilson
# 275               Dwight                     McNeil            McNeil
# 11                 David                Raya Martin              Raya
# 431                Joško                   Gvardiol          Gvardiol
# 541                 Matz                       Sels              Sels
# 307                 Raúl                    Jiménez              Raúl
# 159               Mitoma                      Kaoru            Mitoma
# 389                Trent           Alexander-Arnold  Alexander-Arnold
# 282               Ashley                      Young             Young
# 3                    Kai                    Havertz           Havertz
# 292                Emile                 Smith Rowe        Smith Rowe
# 488               Harvey                     Barnes            Barnes
# 493              Anthony                     Gordon            Gordon
# 14               William                     Saliba            Saliba
# 59                Morgan                     Rogers            Rogers
# 590              Dominic           Solanke-Mitchell           Solanke
# 608                Pedro                      Porro       Pedro Porro
# 520                  Ola                       Aina              Aina
# 106               Mikkel                  Damsgaard         Damsgaard
# 329                 Liam                      Delap             Delap
# 199                 Enzo                  Fernández              Enzo
# 548               Nikola                 Milenković        Milenković
# 649                Tomáš                     Souček            Souček
# 123                Kevin                     Schade            Schade
# 534              Murillo  Santiago Costa dos Santos           Murillo
# 237                 Dean                  Henderson         Henderson
# 216               Robert                    Sánchez           Sánchez
# 310              Antonee                   Robinson          Robinson
# 89               Antoine                    Semenyo           Semenyo
# 253              Ismaïla                       Sarr            I.Sarr
# 473               Marcus                   Rashford          Rashford
# 5                Jurriën                     Timber          J.Timber
# 152           João Pedro         Junqueira de Jesus        João Pedro
# 242        Jean-Philippe                     Mateta            Mateta
# 8                Gabriel           Martinelli Silva        Martinelli
# 494                Lewis                       Hall              Hall
# 177            Georginio                     Rutter         Georginio
# 457                Diogo             Dalot Teixeira             Dalot
# 246               Daniel                      Muñoz             Muñoz
# 423             Bernardo  Veiga de Carvalho e Silva          Bernardo
# 82                 Milos                     Kerkez            Kerkez
# 532               Callum                Hudson-Odoi       Hudson-Odoi
# 354              Facundo                 Buonanotte        Buonanotte
# 189               Moisés             Caicedo Corozo           Caicedo
# 108                 Mark                    Flekken           Flekken
# 646                Lucas   Tolentino Coelho de Lima         L.Paquetá
# 18               Leandro                   Trossard          Trossard
# 490                Bruno  Guimarães Rodriguez Moura          Bruno G.
# 280                James                  Tarkowski         Tarkowski
# 93                Marcus                  Tavernier         Tavernier
# 105               Nathan                    Collins           Collins
# 460            Alejandro                   Garnacho          Garnacho
# 15                Thomas                     Partey            Thomas
# 508                 Nick                       Pope              Pope
# 236                 Marc                      Guéhi             Guéhi
# 631                Aaron                Wan-Bissaka       Wan-Bissaka
# 303                Bernd                       Leno              Leno
# 403             Ibrahima                     Konaté            Konaté
# 686                Mario                     Lemina         Mario Jr.
# 43                  Jhon                      Durán             Duran
# 478             Noussair                   Mazraoui          Mazraoui
# 435                Mateo                    Kovačić           Kovačić
# 276              Vitalii                  Mykolenko         Mykolenko
# 531               Morgan                Gibbs-White       Gibbs-White
# 245               Tyrick                   Mitchell          Mitchell
# 265              Dominic              Calvert-Lewin     Calvert-Lewin
# 52              Emiliano            Martínez Romero          Martinez
# 498     Joelinton Cássio         Apolinário de Lira         Joelinton
# 62                 Youri                  Tielemans         Tielemans
# 347             Arijanet                      Muric             Muric
# 111               Vitaly                     Janelt            Janelt
#
#      now_cost  total_points  ict_index  team  points_per_game  starts  \
# 405       134           156      188.1    12             10.4      15
# 213       112           128      178.3     6              8.0      16
# 13        106           106      174.9     1              7.1      15
# 116        76           105      132.5     4              6.6      16
# 432       149           100      160.4    13              6.2      16
# 607        76            91      130.6    18              5.7      13
# 544        66            90       91.6    16              5.6      15
# 211        82            89      119.3     6              5.9      15
# 670        71            89      134.3    20              5.6      15
# 454        84            81      118.2    14              5.1      16
# 496        87            80      113.8    15              5.7      14
# 302        57            78      116.4     9              4.9      16
# 63         89            78      105.5     2              4.9      14
# 615        98            77      118.0    18              5.9      12
# 208        63            75      116.8     6              5.0      13
# 635        74            75      137.4    19              4.7      16
# 127        62            75       80.3     4              5.8      12
# 404        74            73       85.0    12              4.9      10
# 604        66            71       96.8    18              4.4      13
# 171        58            69       83.7     5              4.9      13
# 2          61            69       64.8     1              4.9      14
# 471        52            67       37.8    14              4.2      16
# 378        56            67       69.5    11              4.5      15
# 694        57            67       83.8    20              4.2      16
# 279        49            66       38.6     8              4.4      15
# 83         55            65       93.2     3              4.1      13
# 452        52            65       88.1    14              4.6       9
# 415        65            65       55.1    12              4.3      15
# 605        63            65      124.5    18              4.1      14
# 100        61            65       81.7     3              4.3      14
# 275        54            65      100.5     8              5.0      13
# 11         56            64       35.2     1              4.0      16
# 431        61            64       97.3    13              4.3      14
# 541        47            64       36.0    16              4.0      16
# 307        55            63       80.9     9              3.9      12
# 159        66            63      109.8     5              3.9      15
# 389        70            62       70.1    12              4.4      13
# 282        47            62       55.9     8              4.8      13
# 3          79            61       93.4     1              4.1      15
# 292        55            61       66.9     9              3.8      14
# 488        62            61       67.2    15              3.8       6
# 493        72            61      115.1    15              4.1      14
# 14         63            61       45.4     1              4.1      15
# 59         53            61       90.1     2              3.8      16
# 590        75            61       84.5    18              4.7      13
# 608        56            61       93.1    18              3.8      14
# 520        49            60       44.1    16              3.8      16
# 106        50            60       86.8     4              3.8      13
# 329        56            59       76.8    10              3.7      15
# 199        51            59       88.8     6              3.9      11
# 548        46            59       49.7    16              3.9      15
# 649        49            56       70.1    19              3.7      12
# 123        51            56       57.7     4              3.5       7
# 534        46            55       64.8    16              3.4      16
# 237        44            55       42.3     7              3.4      16
# 216        48            55       39.4     6              3.7      15
# 310        48            55       82.1     9              3.4      16
# 89         57            55      110.9     3              3.7      15
# 253        57            54       84.1     7              3.4       9
# 473        68            54       68.9    14              3.6      12
# 5          57            53       51.4     1              3.8      13
# 152        59            53       66.2     5              5.3       8
# 242        72            53       65.4     7              3.3      14
# 8          67            53       75.8     1              3.8      10
# 494        46            52       76.9    15              3.2      13
# 177        55            52       53.8     5              3.5      12
# 457        52            51       50.6    14              3.2      16
# 246        47            51       78.5     7              3.2      16
# 423        63            51      110.0    13              3.2      14
# 82         47            50       64.0     3              3.1      16
# 532        54            50       77.8    16              3.3      13
# 354        50            50       82.4    11              3.8      10
# 189        49            49       66.5     6              3.1      16
# 108        45            49       64.4     4              3.1      16
# 646        57            49       71.6    19              3.1      13
# 18         68            49       71.3     1              3.1      10
# 490        61            49       66.3    15              3.1      16
# 280        48            49       59.6     8              3.3      15
# 93         55            48       97.1     3              3.2      13
# 105        45            48       77.3     4              3.0      16
# 460        62            48       77.0    14              3.2      10
# 15         50            48       54.1     1              3.2      13
# 508        50            48       39.1    15              3.2      15
# 236        45            47       64.3     7              2.9      16
# 631        46            47       61.0    19              3.1      14
# 303        50            47       40.2     9              2.9      16
# 403        51            46       34.2    12              3.8      11
# 686        50            46       62.4    20              2.9      15
# 43         58            46       57.0     2              2.9       2
# 478        47            46       44.2    14              2.9      14
# 435        54            46       61.3    13              3.8      10
# 276        43            45       33.8     8              3.5      13
# 531        63            45       84.3    16              3.8      12
# 245        48            45       58.7     7              2.8      16
# 265        55            45       65.0     8              3.0      14
# 52         50            45       34.9     2              2.8      16
# 498        60            45       72.7    15              2.8      16
# 62         55            45       99.7     2              2.8      16
# 347        44            44       45.6    10              2.9      15
# 111        49            44       50.1     4              2.9      13
#
#      element_type  value_season
# 405             3          11.6
# 213             3          11.4
# 13              3          10.0
# 116             3          13.8
# 432             4           6.7
# 607             3          12.0
# 544             4          13.6
# 211             4          10.9
# 670             4          12.5
# 454             3           9.6
# 496             4           9.2
# 302             3          13.7
# 63              4           8.8
# 615             3           7.9
# 208             3          11.9
# 635             3          10.1
# 127             4          12.1
# 404             3           9.9
# 604             3          10.8
# 171             4          11.9
# 2               2          11.3
# 471             1          12.9
# 378             4          12.0
# 694             4          11.8
# 279             1          13.5
# 83              3          11.8
# 452             3          12.5
# 415             2          10.0
# 605             3          10.3
# 100             4          10.7
# 275             3          12.0
# 11              1          11.4
# 431             2          10.5
# 541             1          13.6
# 307             4          11.5
# 159             3           9.5
# 389             2           8.9
# 282             2          13.2
# 3               4           7.7
# 292             3          11.1
# 488             3           9.8
# 493             3           8.5
# 14              2           9.7
# 59              3          11.5
# 590             4           8.1
# 608             2          10.9
# 520             2          12.2
# 106             3          12.0
# 329             4          10.5
# 199             3          11.6
# 548             2          12.8
# 649             3          11.4
# 123             3          11.0
# 534             2          12.0
# 237             1          12.5
# 216             1          11.5
# 310             2          11.5
# 89              3           9.6
# 253             3           9.5
# 473             3           7.9
# 5               2           9.3
# 152             4           9.0
# 242             4           7.4
# 8               3           7.9
# 494             2          11.3
# 177             3           9.5
# 457             2           9.8
# 246             2          10.9
# 423             3           8.1
# 82              2          10.6
# 532             3           9.3
# 354             3          10.0
# 189             3          10.0
# 108             1          10.9
# 646             3           8.6
# 18              3           7.2
# 490             3           8.0
# 280             2          10.2
# 93              3           8.7
# 105             2          10.7
# 460             3           7.7
# 15              3           9.6
# 508             1           9.6
# 236             2          10.4
# 631             2          10.2
# 303             1           9.4
# 403             2           9.0
# 686             3           9.2
# 43              4           7.9
# 478             2           9.8
# 435             3           8.5
# 276             2          10.5
# 531             3           7.1
# 245             2           9.4
# 265             4           8.2
# 52              1           9.0
# 498             3           7.5
# 62              3           8.2
# 347             1          10.0
# 111             3           9.0

# %%
# let's sort by ICT index
players_table_sorted_by_ict_index = players_info_with_selected_columns.sort_values(by='ict_index', ascending=False)
players_table_sorted_by_ict_index.head(100)    # change the number to change the number of rows displayed
# Out:
#               first_name                second_name          web_name  \
# 405              Mohamed                      Salah           M.Salah
# 213                 Cole                     Palmer            Palmer
# 13                Bukayo                       Saka              Saka
# 432               Erling                    Haaland           Haaland
# 635               Jarrod                      Bowen             Bowen
# 670              Matheus   Santos Carneiro Da Cunha             Cunha
# 116                Bryan                     Mbeumo            Mbeumo
# 607                James                   Maddison          Maddison
# 605                Dejan                 Kulusevski        Kulusevski
# 211              Nicolas                    Jackson         N.Jackson
# 454                Bruno           Borges Fernandes       B.Fernandes
# 615                  Son                  Heung-min               Son
# 208                 Noni                    Madueke           Madueke
# 302                 Alex                      Iwobi             Iwobi
# 493              Anthony                     Gordon            Gordon
# 496            Alexander                       Isak              Isak
# 89               Antoine                    Semenyo           Semenyo
# 423             Bernardo  Veiga de Carvalho e Silva          Bernardo
# 159               Mitoma                      Kaoru            Mitoma
# 63                 Ollie                    Watkins           Watkins
# 275               Dwight                     McNeil            McNeil
# 62                 Youri                  Tielemans         Tielemans
# 431                Joško                   Gvardiol          Gvardiol
# 93                Marcus                  Tavernier         Tavernier
# 604              Brennan                    Johnson           Johnson
# 3                    Kai                    Havertz           Havertz
# 83                Justin                   Kluivert          Kluivert
# 608                Pedro                      Porro       Pedro Porro
# 544                Chris                       Wood              Wood
# 235             Eberechi                        Eze               Eze
# 59                Morgan                     Rogers            Rogers
# 328                 Leif                      Davis             Davis
# 199                 Enzo                  Fernández              Enzo
# 452                 Amad                     Diallo              Amad
# 295              Andreas         Hoelgebaum Pereira           Andreas
# 106               Mikkel                  Damsgaard         Damsgaard
# 404                 Luis                       Díaz         Luis Díaz
# 590              Dominic           Solanke-Mitchell           Solanke
# 531               Morgan                Gibbs-White       Gibbs-White
# 253              Ismaïla                       Sarr            I.Sarr
# 694               Jørgen              Strand Larsen     Strand Larsen
# 171                Danny                    Welbeck           Welbeck
# 354              Facundo                 Buonanotte        Buonanotte
# 310              Antonee                   Robinson          Robinson
# 100  Francisco Evanilson            de Lima Barbosa         Evanilson
# 307                 Raúl                    Jiménez              Raúl
# 127                Yoane                      Wissa             Wissa
# 644             Mohammed                      Kudus             Kudus
# 521               Elliot                   Anderson          Anderson
# 246               Daniel                      Muñoz             Muñoz
# 532               Callum                Hudson-Odoi       Hudson-Odoi
# 105               Nathan                    Collins           Collins
# 460            Alejandro                   Garnacho          Garnacho
# 494                Lewis                       Hall              Hall
# 329                 Liam                      Delap             Delap
# 662                Rayan                  Aït-Nouri         Aït-Nouri
# 8                Gabriel           Martinelli Silva        Martinelli
# 426                Kevin                  De Bruyne         De Bruyne
# 76                 Lewis                       Cook              Cook
# 444      Sávio 'Savinho'        Moreira de Oliveira             Sávio
# 498     Joelinton Cássio         Apolinário de Lira         Joelinton
# 413              Dominik                 Szoboszlai        Szoboszlai
# 121                Ethan                    Pinnock           Pinnock
# 12                Declan                       Rice              Rice
# 646                Lucas   Tolentino Coelho de Lima         L.Paquetá
# 18               Leandro                   Trossard          Trossard
# 649                Tomáš                     Souček            Souček
# 389                Trent           Alexander-Arnold  Alexander-Arnold
# 378                Jamie                      Vardy             Vardy
# 473               Marcus                   Rashford          Rashford
# 41                 Lucas                      Digne             Digne
# 488               Harvey                     Barnes            Barnes
# 294                Adama                     Traoré             Adama
# 292                Emile                 Smith Rowe        Smith Rowe
# 372              Wilfred                      Ndidi             Ndidi
# 189               Moisés             Caicedo Corozo           Caicedo
# 490                Bruno  Guimarães Rodriguez Moura          Bruno G.
# 152           João Pedro         Junqueira de Jesus        João Pedro
# 242        Jean-Philippe                     Mateta            Mateta
# 265              Dominic              Calvert-Lewin     Calvert-Lewin
# 534              Murillo  Santiago Costa dos Santos           Murillo
# 2                Gabriel       dos Santos Magalhães           Gabriel
# 108                 Mark                    Flekken           Flekken
# 10                Martin                   Ødegaard          Ødegaard
# 236                 Marc                      Guéhi             Guéhi
# 446                Ilkay                   Gündogan          Gündogan
# 82                 Milos                     Kerkez            Kerkez
# 85                 Dango                   Ouattara           O.Dango
# 277               Iliman                     Ndiaye            Ndiaye
# 686                Mario                     Lemina         Mario Jr.
# 398                 Cody                      Gakpo             Gakpo
# 427               Jérémy                       Doku              Doku
# 75                  Ryan                   Christie          Christie
# 435                Mateo                    Kovačić           Kovačić
# 643                  Max                     Kilman            Kilman
# 631                Aaron                Wan-Bissaka       Wan-Bissaka
# 145               Pervis                  Estupiñán         Estupiñan
# 335                Omari          Giraud-Hutchinson        Hutchinson
# 280                James                  Tarkowski         Tarkowski
# 245               Tyrick                   Mitchell          Mitchell
#
#      now_cost  total_points  ict_index  team  points_per_game  starts  \
# 405       134           156      188.1    12             10.4      15
# 213       112           128      178.3     6              8.0      16
# 13        106           106      174.9     1              7.1      15
# 432       149           100      160.4    13              6.2      16
# 635        74            75      137.4    19              4.7      16
# 670        71            89      134.3    20              5.6      15
# 116        76           105      132.5     4              6.6      16
# 607        76            91      130.6    18              5.7      13
# 605        63            65      124.5    18              4.1      14
# 211        82            89      119.3     6              5.9      15
# 454        84            81      118.2    14              5.1      16
# 615        98            77      118.0    18              5.9      12
# 208        63            75      116.8     6              5.0      13
# 302        57            78      116.4     9              4.9      16
# 493        72            61      115.1    15              4.1      14
# 496        87            80      113.8    15              5.7      14
# 89         57            55      110.9     3              3.7      15
# 423        63            51      110.0    13              3.2      14
# 159        66            63      109.8     5              3.9      15
# 63         89            78      105.5     2              4.9      14
# 275        54            65      100.5     8              5.0      13
# 62         55            45       99.7     2              2.8      16
# 431        61            64       97.3    13              4.3      14
# 93         55            48       97.1     3              3.2      13
# 604        66            71       96.8    18              4.4      13
# 3          79            61       93.4     1              4.1      15
# 83         55            65       93.2     3              4.1      13
# 608        56            61       93.1    18              3.8      14
# 544        66            90       91.6    16              5.6      15
# 235        66            42       90.2     7              3.2      13
# 59         53            61       90.1     2              3.8      16
# 328        45            41       90.1    10              2.6      16
# 199        51            59       88.8     6              3.9      11
# 452        52            65       88.1    14              4.6       9
# 295        50            41       87.9     9              2.7      13
# 106        50            60       86.8     4              3.8      13
# 404        74            73       85.0    12              4.9      10
# 590        75            61       84.5    18              4.7      13
# 531        63            45       84.3    16              3.8      12
# 253        57            54       84.1     7              3.4       9
# 694        57            67       83.8    20              4.2      16
# 171        58            69       83.7     5              4.9      13
# 354        50            50       82.4    11              3.8      10
# 310        48            55       82.1     9              3.4      16
# 100        61            65       81.7     3              4.3      14
# 307        55            63       80.9     9              3.9      12
# 127        62            75       80.3     4              5.8      12
# 644        62            35       79.2    19              3.2      11
# 521        50            44       78.6    16              2.9      11
# 246        47            51       78.5     7              3.2      16
# 532        54            50       77.8    16              3.3      13
# 105        45            48       77.3     4              3.0      16
# 460        62            48       77.0    14              3.2      10
# 494        46            52       76.9    15              3.2      13
# 329        56            59       76.8    10              3.7      15
# 662        48            40       76.7    20              2.5      16
# 8          67            53       75.8     1              3.8      10
# 426        95            42       75.2    13              4.2       7
# 76         50            42       73.3     3              2.8      14
# 444        64            36       73.2    13              2.8       9
# 498        60            45       72.7    15              2.8      16
# 413        63            43       72.3    12              2.9      11
# 121        45            33       72.3     4              2.1      16
# 12         62            33       71.8     1              2.4      14
# 646        57            49       71.6    19              3.1      13
# 18         68            49       71.3     1              3.1      10
# 649        49            56       70.1    19              3.7      12
# 389        70            62       70.1    12              4.4      13
# 378        56            67       69.5    11              4.5      15
# 473        68            54       68.9    14              3.6      12
# 41         47            44       68.8     2              2.8      14
# 488        62            61       67.2    15              3.8       6
# 294        48            42       67.1     9              2.8      10
# 292        55            61       66.9     9              3.8      14
# 372        50            37       66.8    11              2.5      15
# 189        49            49       66.5     6              3.1      16
# 490        61            49       66.3    15              3.1      16
# 152        59            53       66.2     5              5.3       8
# 242        72            53       65.4     7              3.3      14
# 265        55            45       65.0     8              3.0      14
# 534        46            55       64.8    16              3.4      16
# 2          61            69       64.8     1              4.9      14
# 108        45            49       64.4     4              3.1      16
# 10         83            36       64.3     1              4.0       9
# 236        45            47       64.3     7              2.9      16
# 446        65            30       64.2    13              2.0      12
# 82         47            50       64.0     3              3.1      16
# 85         50            39       63.0     3              3.0       5
# 277        54            41       62.9     8              2.7      13
# 686        50            46       62.4    20              2.9      15
# 398        71            43       62.3    12              2.9       7
# 427        62            40       62.3    13              3.3       7
# 75         49            33       62.1     3              2.2      13
# 435        54            46       61.3    13              3.8      10
# 643        45            38       61.0    19              2.4      16
# 631        46            47       61.0    19              3.1      14
# 145        51            19       60.5     5              1.5      10
# 335        52            39       60.4    10              2.6      15
# 280        48            49       59.6     8              3.3      15
# 245        48            45       58.7     7              2.8      16
#
#      element_type  value_season
# 405             3          11.6
# 213             3          11.4
# 13              3          10.0
# 432             4           6.7
# 635             3          10.1
# 670             4          12.5
# 116             3          13.8
# 607             3          12.0
# 605             3          10.3
# 211             4          10.9
# 454             3           9.6
# 615             3           7.9
# 208             3          11.9
# 302             3          13.7
# 493             3           8.5
# 496             4           9.2
# 89              3           9.6
# 423             3           8.1
# 159             3           9.5
# 63              4           8.8
# 275             3          12.0
# 62              3           8.2
# 431             2          10.5
# 93              3           8.7
# 604             3          10.8
# 3               4           7.7
# 83              3          11.8
# 608             2          10.9
# 544             4          13.6
# 235             3           6.4
# 59              3          11.5
# 328             2           9.1
# 199             3          11.6
# 452             3          12.5
# 295             3           8.2
# 106             3          12.0
# 404             3           9.9
# 590             4           8.1
# 531             3           7.1
# 253             3           9.5
# 694             4          11.8
# 171             4          11.9
# 354             3          10.0
# 310             2          11.5
# 100             4          10.7
# 307             4          11.5
# 127             4          12.1
# 644             3           5.6
# 521             3           8.8
# 246             2          10.9
# 532             3           9.3
# 105             2          10.7
# 460             3           7.7
# 494             2          11.3
# 329             4          10.5
# 662             2           8.3
# 8               3           7.9
# 426             3           4.4
# 76              3           8.4
# 444             3           5.6
# 498             3           7.5
# 413             3           6.8
# 121             2           7.3
# 12              3           5.3
# 646             3           8.6
# 18              3           7.2
# 649             3          11.4
# 389             2           8.9
# 378             4          12.0
# 473             3           7.9
# 41              2           9.4
# 488             3           9.8
# 294             3           8.8
# 292             3          11.1
# 372             3           7.4
# 189             3          10.0
# 490             3           8.0
# 152             4           9.0
# 242             4           7.4
# 265             4           8.2
# 534             2          12.0
# 2               2          11.3
# 108             1          10.9
# 10              3           4.3
# 236             2          10.4
# 446             3           4.6
# 82              2          10.6
# 85              3           7.8
# 277             4           7.6
# 686             3           9.2
# 398             4           6.1
# 427             3           6.5
# 75              3           6.7
# 435             3           8.5
# 643             2           8.4
# 631             2          10.2
# 145             2           3.7
# 335             3           7.5
# 280             2          10.2
# 245             2           9.4

# %%
from pulp import LpProblem, LpVariable, LpMaximize, lpSum, LpStatus
model = LpProblem(name="FantasyFootbal", sense=LpMaximize)

players_json = players_info_with_selected_columns.to_dict(orient='records')

players_vars = {i: LpVariable(name=f"player_{i}", cat="Binary") for i in range(len(players_json))}

# objective function
# motivation: Our objective function is to get a squad with many points
#             high ICT index means they are likely to perform more and bring points.
#             value season means we can get many points with small amount of money. There are
#             many unknown player with smaller selection % by managers and have many points. These
#             players might provide edge against other managers.
#             Starts: We want players who are starters
#Limitations: You are likely to drop points in the benches because total points include points
#             accumulated by bench players. This is not holy grail. It is aimed to reduce headache during
#             selection. Feel free to adjust your selection.
#Weights:     These determines which is the most important thing to consider when choosing our players.
#             Total weight should be equal to 1 (0.6 + 0.2 + 0.1 + 0.1). Feel free to tweak the weights to get different result.
#             
model += lpSum(
    players_vars[i] * (
        players_json[i]['total_points'] * 0.5 +  # change values here to get different results
        players_json[i]['ict_index'] * 0.3 +     # change values here to get different results
        players_json[i]['value_season'] * 0.1 + # change values here to get different results
        players_json[i]['starts'] * 0.1         # change values here to get different results
    )
    for i in range(len(players_json))
)

#budget constraint
budget = 1000
model += lpSum(players_vars[i] * players_json[i]['now_cost'] for i in range(len(players_json))) <= budget  # players cost should exceed the budget

# team composition
model += lpSum(players_vars[i] for i in range(len(players_json)) if players_json[i]['element_type'] == 1) == 2 # two goalkeepers
model += lpSum(players_vars[i] for i in range(len(players_json)) if players_json[i]['element_type'] == 2) == 5 # 5 defenders
model += lpSum(players_vars[i] for i in range(len(players_json)) if players_json[i]['element_type'] == 3) == 5 # 5 midfielders
model += lpSum(players_vars[i] for i in range(len(players_json)) if players_json[i]['element_type'] == 4) == 3 # 3 forwards

# team size
model += lpSum(players_vars.values()) == 15

# max 3 players per club
for team_id in range(1, 21):
    model += lpSum(players_vars[i] for i in range(len(players_json)) if players_json[i]['team'] == team_id) <= 3

# solve the problem
status = model.solve()
print(f"Problem Status: {LpStatus[status]}")

# cleaning our data for display
selected_players = [players_json[i] for i in range(len(players_json)) if players_vars[i].value() == 1]

element_type_to_position = {
    1: 'GK',
    2: 'DEF',
    3: 'MID',
    4: 'FWD'
}

teams_info = pd.json_normalize(json.loads(fpl_data), 'teams', sep='_')
team_mapper = teams_info.set_index("id")["name"].to_dict()


selected_players_table = pd.DataFrame(selected_players)

selected_players_table['element_type'] = selected_players_table['element_type'].map(element_type_to_position)
selected_players_table['team'] = selected_players_table['team'].map(team_mapper)

# organizing columns
selected_players_table["Player Name"] = selected_players_table["web_name"]
selected_players_table["Price"] = selected_players_table["now_cost"]
selected_players_table["Total points"] = selected_players_table["total_points"]
selected_players_table["ICT"] = selected_players_table["ict_index"]
selected_players_table["Starts"] = selected_players_table["starts"]
selected_players_table["ROI"] = selected_players_table["value_season"]
selected_players_table["Position"] = selected_players_table["element_type"]

columns = [
    "Player Name",
    "Price",
    "Total points",
    "ICT",
    "Starts",
    "ROI",
    "Position",
    "team",
    "element_type"
]

total_row = {
    "Player Name" : "Total",
    "Price" : selected_players_table["Price"].sum(),
    "Total points" : selected_players_table["Total points"].sum(),
    "ICT": '',
    "Starts": '',
    "ROI": '',
    "Position": '',
    "team": ''
}

selected_players_table = pd.concat([selected_players_table, pd.DataFrame([total_row])], ignore_index=True)

selected_players_table[columns].sort_values(by='element_type').drop(columns=['element_type']).reset_index(drop=True)
# Out:
# Problem Status: Optimal
#     Player Name  Price  Total points    ICT Starts   ROI Position  \
# 0         Muñoz     47            51   78.5     16  10.9      DEF
# 1      Robinson     48            55   82.1     16  11.5      DEF
# 2      Gvardiol     61            64   97.3     14  10.5      DEF
# 3          Hall     46            52   76.9     13  11.3      DEF
# 4   Pedro Porro     56            61   93.1     14  10.9      DEF
# 5       Welbeck     58            69   83.7     13  11.9      FWD
# 6          Wood     66            90   91.6     15  13.6      FWD
# 7         Cunha     71            89  134.3     15  12.5      FWD
# 8       Flekken     45            49   64.4     16  10.9       GK
# 9          Sels     47            64   36.0     16  13.6       GK
# 10       Mbeumo     76           105  132.5     16  13.8      MID
# 11       Palmer    112           128  178.3     16  11.4      MID
# 12        Iwobi     57            78  116.4     16  13.7      MID
# 13      M.Salah    134           156  188.1     15  11.6      MID
# 14     Maddison     76            91  130.6     13  12.0      MID
# 15        Total   1000          1202
#
#               team
# 0   Crystal Palace
# 1           Fulham
# 2         Man City
# 3        Newcastle
# 4            Spurs
# 5         Brighton
# 6    Nott'm Forest
# 7           Wolves
# 8        Brentford
# 9    Nott'm Forest
# 10       Brentford
# 11         Chelsea
# 12          Fulham
# 13       Liverpool
# 14           Spurs
# 15
